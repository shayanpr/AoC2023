# %% [markdown]
# # **Advent of Code**
#
# This is an annual event in which a set of daily challenges are provided, for programmers of all walks of life to work on. [Advent of Code](adventofcode.com) is highly recommended for any programmers out there.

# %% [markdown]
# ## Day 3: Gear Ratios
# You and the Elf eventually reach a gondola lift station; he says the gondola lift will take you up to the water source, but this is as far as he can bring you. You go inside.
#
# It doesn't take long to find the gondolas, but there seems to be a problem: they're not moving.
#
# "Aaah!"
#
# You turn around to see a slightly-greasy Elf with a wrench and a look of surprise. "Sorry, I wasn't expecting anyone! The gondola lift isn't working right now; it'll still be a while before I can fix it." You offer to help.
#
# The engineer explains that an engine part seems to be missing from the engine, but nobody can figure out which one. If you can _add up all the part numbers_ in the engine schematic, it should be easy to work out which part is missing.
#
# The engine schematic (your puzzle input) consists of a visual representation of the engine. There are lots of numbers and symbols you don't really understand, but apparently _any number adjacent to a symbol_, even diagonally, is a "part number" and should be included in your sum. (Periods (.) do not count as a symbol.)
#
# Here is an example engine schematic:
#
#
# ```
# 467..114..
# ...*......
# ..35..633.
# ......#...
# 617*......
# .....+.58.
# ..592.....
# ......755.
# ...$.*....
# .664.598..
# ```
#
# In this schematic, two numbers are not part numbers because they are _not_ adjacent to a symbol: 114 (top right) and 58 (middle right). Every other number is adjacent to a symbol and so is a part number; their sum is 4361.
#
# Of course, the actual engine schematic is much larger. _What is the sum of all of the part numbers in the engine schematic?_

# %%
puzzle_input = ""
file_number = 3
with open(file=f"inputs/{file_number}.txt", mode = 'r') as f:
    puzzle_input = f.read()

# %%
symbols = set(puzzle_input)
numerals = set('0123456789')
symbols = symbols.difference(numerals)
symbols = symbols.difference(set({'.', '\n'}))

# %%
print(symbols)
print(numerals)
# Out:
# {'@', '+', '-', '%', '&', '=', '/', '#', '$', '*'}
# {'7', '0', '9', '5', '3', '4', '6', '2', '8', '1'}

# %%
puzzle_input = puzzle_input.split('\n')

# %%
len(puzzle_input[0])
# Out:
# 140

# %%
print(puzzle_input[1])
print(puzzle_input[1].split('.'))
# Out:
# ...............415..*.........@......*...627*...................945*.............144/.506............................*......514...*...150...
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '415', '', '*', '', '', '', '', '', '', '', '', '@', '', '', '', '', '', '*', '', '', '627*', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '945*', '', '', '', '', '', '', '', '', '', '', '', '', '144/', '506', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '*', '', '', '', '', '', '514', '', '', '*', '', '', '150', '', '', '']

# %%
numbers = []
for row in puzzle_input:
    nu = row.replace('.' , ' ')
    for symbol in list(symbols):
        nu = nu.replace(symbol , ' ')
        
    numbers.append(nu)

# %%
numbers = [numbers[i].split() for i in range(len(numbers))]

# %%
len(numbers)
# Out:
# 140

# %%
for i in range(10):
    print(numbers[i][:50])
    print(puzzle_input[i][:50])
# Out:
# ['358', '31', '339', '669', '598', '328', '575', '447', '650', '964', '692']
# .......358..........31.....339.....669............
# ['415', '627', '945', '144', '506', '514', '150']
# ...............415..*.........@......*...627*.....
# ['182', '873', '756', '737', '784', '568', '667', '258', '741', '707', '84', '520']
# .........182..+.....873.756.......737........784..
# ['579', '258', '274', '739', '157', '580', '893', '696', '889']
# ..579...@.........$........*..........258.........
# ['875', '173', '109', '896', '959', '677', '636']
# .....*.........875.........173.........*..........
# ['961', '907', '569', '756', '681']
# ......961..$............-...............907...569.
# ['478', '616', '30', '221', '552', '33', '258', '343', '488', '682', '526', '422', '764']
# ...........478...616.....30.....221*..............
# ['7', '550', '878']
# ................+.................................
# ['171', '275', '401', '50', '43', '123', '949', '135', '331', '495']
# ...171..275............#.....................401..
# ['48', '662', '100', '590', '566', '15', '426', '774']
# ........*...48@.662.100...............590...*.....

# %%
part_numbers = []
for i in range(140):

    #print(puzzle_input[i])
    #print(numbers[i])

    
    for j,num in enumerate(numbers[i]):
        #print(type(puzzle_input[i]))
        start = puzzle_input[i].find(str(num))
        end = start + len(num)

        surround = []
        
        if i ==0 :
            surround.extend(puzzle_input[i][max(0,start-1): min(139,end+1)])
            surround.extend(puzzle_input[i+1][max(0,start-1): min(139,end+1)])
        elif i ==139:
            surround.extend(puzzle_input[i-1][max(0,start-1): min(139,end+1)])
            surround.extend(puzzle_input[i][max(0,start-1): min(139,end+1)])
        else:
            surround.extend(puzzle_input[i-1][max(0,start-1): min(139,end+1)])
            surround.extend(puzzle_input[i][max(0,start-1): min(139,end+1)])
            surround.extend(puzzle_input[i+1][max(0,start-1): min(139,end+1)])
        #print(surround)    
        surround = set(surround)
        if surround & symbols:
            part_numbers.append(int(num))

# %%
part_numbers
# Out:
# [31,
#  339,
#  669,
#  575,
#  964,
#  692,
#  415,
#  627,
#  945,
#  144,
#  506,
#  182,
#  873,
#  756,
#  737,
#  784,
#  667,
#  258,
#  741,
#  707,
#  520,
#  579,
#  258,
#  274,
#  739,
#  157,
#  580,
#  893,
#  696,
#  889,
#  875,
#  173,
#  109,
#  896,
#  959,
#  677,
#  636,
#  961,
#  907,
#  756,
#  681,
#  478,
#  616,
#  30,
#  221,
#  552,
#  33,
#  258,
#  343,
#  488,
#  682,
#  526,
#  7,
#  878,
#  275,
#  401,
#  50,
#  43,
#  123,
#  949,
#  135,
#  331,
#  495,
#  48,
#  662,
#  100,
#  590,
#  566,
#  426,
#  774,
#  944,
#  28,
#  307,
#  361,
#  55,
#  24,
#  447,
#  787,
#  266,
#  361,
#  161,
#  405,
#  785,
#  146,
#  654,
#  760,
#  80,
#  17,
#  84,
#  830,
#  140,
#  745,
#  972,
#  406,
#  864,
#  762,
#  695,
#  327,
#  512,
#  414,
#  960,
#  1,
#  374,
#  264,
#  833,
#  336,
#  252,
#  10,
#  518,
#  777,
#  811,
#  103,
#  774,
#  433,
#  951,
#  44,
#  957,
#  216,
#  614,
#  521,
#  232,
#  232,
#  802,
#  779,
#  759,
#  307,
#  941,
#  512,
#  865,
#  662,
#  816,
#  681,
#  21,
#  290,
#  364,
#  258,
#  195,
#  535,
#  261,
#  650,
#  152,
#  514,
#  411,
#  788,
#  186,
#  91,
#  279,
#  268,
#  639,
#  864,
#  933,
#  73,
#  203,
#  187,
#  362,
#  861,
#  389,
#  847,
#  135,
#  6,
#  529,
#  202,
#  96,
#  998,
#  989,
#  288,
#  650,
#  349,
#  655,
#  854,
#  425,
#  531,
#  848,
#  594,
#  68,
#  767,
#  732,
#  410,
#  185,
#  91,
#  773,
#  579,
#  454,
#  757,
#  568,
#  742,
#  70,
#  478,
#  769,
#  182,
#  568,
#  861,
#  993,
#  48,
#  893,
#  835,
#  798,
#  473,
#  965,
#  691,
#  306,
#  531,
#  938,
#  200,
#  335,
#  432,
#  343,
#  360,
#  836,
#  951,
#  341,
#  360,
#  958,
#  728,
#  585,
#  902,
#  696,
#  190,
#  808,
#  451,
#  272,
#  59,
#  641,
#  822,
#  289,
#  36,
#  509,
#  464,
#  10,
#  604,
#  102,
#  450,
#  797,
#  575,
#  488,
#  402,
#  847,
#  434,
#  844,
#  478,
#  147,
#  826,
#  297,
#  257,
#  492,
#  81,
#  560,
#  661,
#  379,
#  884,
#  700,
#  646,
#  914,
#  659,
#  513,
#  621,
#  790,
#  472,
#  843,
#  734,
#  738,
#  989,
#  817,
#  727,
#  131,
#  767,
#  685,
#  727,
#  478,
#  247,
#  649,
#  82,
#  507,
#  504,
#  909,
#  707,
#  922,
#  701,
#  213,
#  833,
#  866,
#  630,
#  606,
#  102,
#  183,
#  281,
#  225,
#  108,
#  772,
#  109,
#  96,
#  685,
#  155,
#  811,
#  220,
#  106,
#  488,
#  233,
#  590,
#  551,
#  287,
#  874,
#  956,
#  513,
#  829,
#  487,
#  350,
#  338,
#  55,
#  464,
#  695,
#  227,
#  802,
#  822,
#  960,
#  295,
#  946,
#  587,
#  859,
#  204,
#  246,
#  644,
#  925,
#  210,
#  129,
#  102,
#  832,
#  558,
#  404,
#  817,
#  870,
#  791,
#  120,
#  483,
#  406,
#  797,
#  68,
#  929,
#  87,
#  411,
#  458,
#  143,
#  721,
#  706,
#  694,
#  369,
#  899,
#  417,
#  930,
#  78,
#  174,
#  276,
#  313,
#  394,
#  773,
#  916,
#  37,
#  384,
#  355,
#  180,
#  902,
#  829,
#  823,
#  408,
#  960,
#  871,
#  756,
#  22,
#  956,
#  622,
#  461,
#  749,
#  297,
#  557,
#  877,
#  863,
#  968,
#  946,
#  700,
#  507,
#  583,
#  571,
#  499,
#  803,
#  942,
#  782,
#  726,
#  688,
#  580,
#  905,
#  446,
#  397,
#  629,
#  831,
#  760,
#  427,
#  473,
#  729,
#  298,
#  618,
#  562,
#  865,
#  553,
#  267,
#  12,
#  971,
#  472,
#  714,
#  712,
#  173,
#  780,
#  948,
#  750,
#  311,
#  425,
#  336,
#  882,
#  913,
#  369,
#  942,
#  209,
#  791,
#  626,
#  787,
#  954,
#  725,
#  806,
#  447,
#  679,
#  706,
#  922,
#  217,
#  962,
#  104,
#  278,
#  382,
#  820,
#  454,
#  418,
#  748,
#  577,
#  655,
#  254,
#  383,
#  316,
#  243,
#  363,
#  709,
#  714,
#  224,
#  479,
#  817,
#  428,
#  318,
#  457,
#  756,
#  562,
#  253,
#  498,
#  392,
#  394,
#  768,
#  751,
#  202,
#  201,
#  525,
#  430,
#  953,
#  456,
#  310,
#  58,
#  863,
#  675,
#  117,
#  447,
#  940,
#  905,
#  889,
#  542,
#  723,
#  591,
#  956,
#  743,
#  156,
#  791,
#  84,
#  538,
#  643,
#  659,
#  66,
#  127,
#  585,
#  238,
#  866,
#  80,
#  979,
#  300,
#  102,
#  465,
#  705,
#  332,
#  142,
#  500,
#  336,
#  419,
#  116,
#  719,
#  237,
#  81,
#  461,
#  931,
#  426,
#  434,
#  489,
#  420,
#  459,
#  277,
#  746,
#  848,
#  804,
#  445,
#  197,
#  658,
#  342,
#  461,
#  630,
#  930,
#  804,
#  299,
#  270,
#  257,
#  283,
#  357,
#  702,
#  644,
#  587,
#  460,
#  406,
#  162,
#  121,
#  360,
#  228,
#  847,
#  666,
#  612,
#  178,
#  527,
#  872,
#  762,
#  267,
#  307,
#  606,
#  224,
#  13,
#  455,
#  152,
#  919,
#  485,
#  623,
#  968,
#  810,
#  281,
#  693,
#  520,
#  909,
#  586,
#  794,
#  229,
#  88,
#  385,
#  363,
#  636,
#  619,
#  238,
#  45,
#  982,
#  145,
#  803,
#  426,
#  213,
#  536,
#  708,
#  170,
#  360,
#  220,
#  16,
#  796,
#  283,
#  652,
#  89,
#  894,
#  975,
#  27,
#  409,
#  978,
#  445,
#  538,
#  822,
#  274,
#  491,
#  329,
#  468,
#  213,
#  47,
#  568,
#  706,
#  232,
#  74,
#  965,
#  685,
#  125,
#  824,
#  725,
#  548,
#  77,
#  391,
#  253,
#  769,
#  183,
#  687,
#  921,
#  913,
#  162,
#  724,
#  220,
#  880,
#  404,
#  466,
#  411,
#  894,
#  196,
#  90,
#  1,
#  360,
#  422,
#  334,
#  878,
#  322,
#  573,
#  649,
#  475,
#  450,
#  249,
#  905,
#  879,
#  829,
#  290,
#  680,
#  244,
#  9,
#  596,
#  326,
#  359,
#  723,
#  826,
#  773,
#  790,
#  642,
#  617,
#  979,
#  776,
#  562,
#  363,
#  915,
#  704,
#  401,
#  32,
#  681,
#  261,
#  351,
#  896,
#  896,
#  493,
#  88,
#  925,
#  17,
#  265,
#  893,
#  778,
#  222,
#  873,
#  872,
#  635,
#  852,
#  559,
#  456,
#  128,
#  179,
#  336,
#  985,
#  77,
#  482,
#  502,
#  404,
#  206,
#  41,
#  761,
#  782,
#  514,
#  130,
#  168,
#  46,
#  195,
#  619,
#  544,
#  191,
#  419,
#  842,
#  64,
#  206,
#  816,
#  670,
#  84,
#  78,
#  966,
#  564,
#  185,
#  250,
#  464,
#  762,
#  412,
#  302,
#  27,
#  653,
#  738,
#  596,
#  563,
#  148,
#  928,
#  565,
#  60,
#  158,
#  503,
#  931,
#  710,
#  272,
#  851,
#  603,
#  445,
#  382,
#  837,
#  956,
#  970,
#  377,
#  56,
#  926,
#  172,
#  201,
#  261,
#  606,
#  347,
#  655,
#  468,
#  746,
#  332,
#  681,
#  703,
#  824,
#  478,
#  595,
#  245,
#  918,
#  875,
#  875,
#  965,
#  676,
#  745,
#  858,
#  479,
#  132,
#  354,
#  776,
#  820,
#  291,
#  59,
#  668,
#  956,
#  921,
#  312,
#  803,
#  613,
#  78,
#  522,
#  665,
#  692,
#  253,
#  863,
#  498,
#  258,
#  426,
#  108,
#  357,
#  794,
#  594,
#  664,
#  525,
#  885,
#  353,
#  823,
#  590,
#  111,
#  420,
#  374,
#  144,
#  80,
#  164,
#  928,
#  289,
#  185,
#  659,
#  772,
#  361,
#  436,
#  14,
#  296,
#  453,
#  753,
#  368,
#  733,
#  167,
#  675,
#  22,
#  502,
#  443,
#  413,
#  200,
#  616,
#  143,
#  768,
#  404,
#  378,
#  538,
#  579,
#  311,
#  267,
#  445,
#  138,
#  158,
#  323,
#  586,
#  825,
#  318,
#  260,
#  618,
#  229,
#  865,
#  353,
#  834,
#  68,
#  981,
#  606,
#  432,
#  870,
#  749,
#  215,
#  18,
#  977,
#  385,
#  95,
#  182,
#  773,
#  165,
#  816,
#  391,
#  439,
#  682,
#  249,
#  435,
#  400,
#  261,
#  119,
#  921,
#  630,
#  92,
#  744,
#  780,
#  205,
#  347,
#  152,
#  950,
#  592,
#  152,
#  789,
#  949,
#  530,
#  248,
#  957,
#  957,
#  572,
#  601,
#  766,
#  112,
#  113,
#  656,
#  837,
#  320,
#  518,
#  125,
#  900,
#  434,
#  224,
#  235,
#  498,
#  175,
#  930,
#  880,
#  296,
#  118,
#  328,
#  405,
#  801,
#  804,
#  590,
#  770,
#  276,
#  297,
#  726,
#  966,
#  997,
#  165,
#  25,
#  983,
#  992,
#  966,
#  92,
#  108,
#  475,
#  769,
#  897,
#  123,
#  122,
#  579,
#  811,
#  708,
#  767,
#  386,
#  558,
#  708,
#  230,
#  161,
#  177,
#  940,
#  903,
#  706,
#  785,
#  93,
#  381,
#  621,
#  652,
#  886,
#  157,
#  204,
#  418,
#  62,
#  422,
#  537,
#  479,
#  499,
#  96,
#  656,
#  751,
#  293,
#  759,
#  174,
#  32,
#  610,
#  105,
#  416,
#  242,
#  746,
#  259,
#  591,
#  653,
#  103,
#  62,
#  585,
#  567,
#  216,
#  840,
#  612,
#  588,
#  676,
#  202,
#  301,
#  632,
#  392,
#  667,
#  457,
#  134,
#  165,
#  728,
#  339,
#  74,
#  402,
#  581,
#  518,
#  823,
#  874,
#  102,
#  74,
#  ...]

# %%
print(sum(part_numbers))
# Out:
# 538888
